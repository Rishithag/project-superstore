# %%
 import os

# %%
os.chdir("C:/Users/Lenovo/Desktop/data")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
store=pd.read_excel("SuperStore.xlsx")
store
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 3          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 4         11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 5         24  US-2017-156909 2017-07-16 2017-07-18    Second Class
# 6         25  CA-2015-106320 2015-09-25 2015-09-30  Standard Class
# 7         28  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# 8         30  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# 9         37  CA-2016-117590 2016-12-08 2016-12-10     First Class
# 10        39  CA-2015-117415 2015-12-27 2015-12-31  Standard Class
# 11        40  CA-2015-117415 2015-12-27 2015-12-31  Standard Class
# 12        52  CA-2015-115742 2015-04-18 2015-04-22  Standard Class
# ...

# %%
store.corr()
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.017164  0.001696 -0.000246  0.031848  0.008775
# Postal Code  0.017164     1.000000 -0.011786  0.013700  0.106736 -0.026335
# Sales        0.001696    -0.011786  1.000000  0.437464 -0.028576  0.173510
# Quantity    -0.000246     0.013700  0.437464  1.000000 -0.015695  0.061213
# Discount     0.031848     0.106736 -0.028576 -0.015695  1.000000 -0.483769
# Profit       0.008775    -0.026335  0.173510  0.061213 -0.483769  1.000000

# %%
store.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
store.describe()
# Out:
#             Row ID   Postal Code        Sales     Quantity     Discount  \
# count  2121.000000   2121.000000  2121.000000  2121.000000  2121.000000
# mean   5041.643564  55726.556341   349.834887     3.785007     0.173923
# std    2885.740258  32261.888225   503.179145     2.251620     0.181547
# min       1.000000   1040.000000     1.892000     1.000000     0.000000
# 25%    2568.000000  22801.000000    47.040000     2.000000     0.000000
# 50%    5145.000000  60505.000000   182.220000     3.000000     0.200000
# 75%    7534.000000  90032.000000   435.168000     5.000000     0.300000
# max    9991.000000  99301.000000  4416.174000    14.000000     0.700000
#
#             Profit
# count  2121.000000
# mean      8.699327
# std     136.049246
# min   -1862.312400
# 25%     -12.849000
# 50%       7.774800
# 75%      33.726600
# max    1013.127000

# %%
quantity=store['Quantity']
sales=store['Sales']

# %%
plt.plot(quantity,sales,'o')
plt.ylabel("Sales")
plt.xlabel("Quantity")
# Out:
# Text(0.5, 0, 'Quantity')

# %%
means=store["Sales"].mean()

# %%
means
# Out:
# 349.83488698727007

# %%
plt.plot(quantity,sales,'o')
plt.ylabel("Quantity")
plt.xlabel("Sales")
plt.axhline(means,color='r',linestyle='-')
plt.show()

# %%
import statsmodels.api as sm
model=sm.OLS(sales,quantity).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.455
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     1768.
# Date:                Thu, 13 Jun 2019   Prob (F-statistic):          1.84e-281
# Time:                        09:45:36   Log-Likelihood:                -15979.
# No. Observations:                2121   AIC:                         3.196e+04
# Df Residuals:                    2120   BIC:                         3.197e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Quantity      93.8206      2.232     42.043      0.000      89.444      98.197
# ...

# %%
import seaborn as sns
sns.pairplot(store)

# %%
corr=store.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
plt.plot(quantity,sales,'o')
plt.ylabel("Sales")
plt.xlabel("Quantity")
plt.axhline(means,color='r',linestyle='-')
sns.regplot(x='Quantity',y='Sales',data=store)
